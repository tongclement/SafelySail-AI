# %%
from ultralytics import YOLO
from PIL import Image
import cv2

# %%
model = YOLO("yolov8n-seg.pt")

# %%
results = model.train(data="/Users/clementtongpersonal/Desktop/Programming/2022/SafelySail-AI/dataset2/data.yaml",epochs=290) #todo: should not use abs path but relative path didn't work for some reason
#model.trainer.get
# Out:
# Ultralytics YOLOv8.0.32 🚀 Python-3.10.8 torch-1.13.1 CPU
# ...

# %%
val_results=model.val()
# Out:
# Ultralytics YOLOv8.0.32 🚀 Python-3.10.8 torch-1.13.1 CPU
# YOLOv8n-seg summary (fused): 195 layers, 3259234 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /Users/clementtongpersonal/Desktop/Programming/2022/SafelySail-AI/dataset2/valid/labels.cache... 8 images, 0 backgrounds, 0 corrupt: 100%|██████████| 8/8 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
#                    all          8         59      0.767       0.57      0.681      0.508      0.651      0.423      0.499      0.331
#                   boat          8         11      0.621      0.545      0.581       0.46      0.605      0.545       0.57      0.352
#                   land          8         17      0.824      0.353       0.52      0.337      0.772      0.399      0.519      0.316
# ...

# %%
predict_results=model(source="/Users/clementtongpersonal/Desktop/Programming/2022/SafelySail-AI/dataset2/test/images/420-Collision-and-Capsizes_mp4-50_jpg.rf.0f42e87aec1ba646c0a3a6d789f13055.jpg",show=True)
print(predict_results)
# Out:
# 2023-02-21 07:32:58.391 python[46029:6864821] IMKClient Stall detected, *please Report* your user scenario attaching a spindump (or sysdiagnose) that captures the problem - (imkxpc_bundleIdentifierWithReply:) block performed very slowly (11.50 secs).
# image 1/1 /Users/clementtongpersonal/Desktop/Programming/2022/SafelySail-AI/dataset2/test/images/420-Collision-and-Capsizes_mp4-50_jpg.rf.0f42e87aec1ba646c0a3a6d789f13055.jpg: 384x640 81.3ms
# Speed: 1.4ms pre-process, 81.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# [Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
# type: <class 'torch.Tensor'>
# shape: torch.Size([0, 6])
# dtype: torch.float32
#  + tensor([], size=(0, 6))]

# %%
#dataset2/test/images/20-Knots-in-a-29er-on-GO-PRO_mp4-59_jpg.rf.7872cecbdb148a168482bb75d537760b.jpg

predict_results=model(source="/Users/clementtongpersonal/Desktop/Programming/2022/SafelySail-AI/dataset2/train/images/GoPro-laser-pico-sailing-Kefalonia-Greece-15-kph_mp4-117_jpg.rf.b96d1751152630da85f1811b897e37a6.jpg",show=True)
#print(predict_results)

for r in predict_results:
    print(r)
# Out:
# image 1/1 /Users/clementtongpersonal/Desktop/Programming/2022/SafelySail-AI/dataset2/train/images/GoPro-laser-pico-sailing-Kefalonia-Greece-15-kph_mp4-117_jpg.rf.b96d1751152630da85f1811b897e37a6.jpg: 384x640 76.6ms
# Speed: 0.5ms pre-process, 76.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# tensor([], size=(0, 6))

# %%
success = model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.0.32 🚀 Python-3.10.8 torch-1.13.1 CPU
#
# PyTorch: starting from runs/segment/train5/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 42, 8400), (1, 32, 160, 160)) (6.4 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 9.0 MB/s eta 0:00:0000:0100:01m
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.13.0...
# ONNX: export success ✅ 6.9s, saved as runs/segment/train5/weights/best.onnx (12.6 MB)
#
# Export complete (7.1s)
# Results saved to /Users/clementtongpersonal/Desktop/Programming/2022/SafelySail-AI/runs/segment/train5/weights
# ...

# %%
model.info(verbose=True)  # Print model information
model.export(format="saved_model")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniforge3/envs/safelysailAIv2/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#
# File ~/miniforge3/envs/safelysailAIv2/lib/python3.10/subprocess.py:1943, in Popen._wait(self, timeout)
#    1942     break  # Another thread waited.
# -> 1943 (pid, sts) = self._try_wait(0)
#    1944 # Check the pid and loop as waitpid has been known to
#    1945 # return 0 even without WNOHANG in odd situations.
#    1946 # http://bugs.python.org/issue14396.
#
# ...
